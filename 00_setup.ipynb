# %%
# %sql
SELECT
    current_catalog() AS catalog_name,
    current_schema() AS schema_name;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog_name</th><th>schema_name</th></tr></thead><tbody><tr><td>workspace</td><td>default</td></tr></tbody></table></div>

# %%
# %sql
SHOW SCHEMAS IN workspace;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>analytics</td></tr><tr><td>dbrx_12daysofdemos</td></tr><tr><td>default</td></tr><tr><td>dev_bronze</td></tr><tr><td>dev_gold</td></tr><tr><td>dev_silver</td></tr><tr><td>information_schema</td></tr></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.portfolio_bronze;
CREATE SCHEMA IF NOT EXISTS workspace.portfolio_silver;
CREATE SCHEMA IF NOT EXISTS workspace.portfolio_gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW SCHEMAS IN workspace;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>analytics</td></tr><tr><td>dbrx_12daysofdemos</td></tr><tr><td>default</td></tr><tr><td>dev_bronze</td></tr><tr><td>dev_gold</td></tr><tr><td>dev_silver</td></tr><tr><td>information_schema</td></tr><tr><td>portfolio_bronze</td></tr><tr><td>portfolio_gold</td></tr><tr><td>portfolio_silver</td></tr></tbody></table></div>

# %%
# %sql
-- app-4btdlf sales-insights
GRANT USE CATALOG ON CATALOG workspace
TO `ab891a06-f6aa-456d-b3e2-f74e92402420`;

GRANT USE SCHEMA ON SCHEMA workspace.portfolio_gold
TO `ab891a06-f6aa-456d-b3e2-f74e92402420`;

GRANT SELECT ON VIEW workspace.portfolio_gold.sales_details
TO `ab891a06-f6aa-456d-b3e2-f74e92402420`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
